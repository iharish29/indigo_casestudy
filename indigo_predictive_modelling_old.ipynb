# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Read input files

# %%
df_cd = pd.read_csv("/Users/harish/Desktop/DS_codes/indigo/common_data.csv")
df_ay = pd.read_csv("/Users/harish/Desktop/DS_codes/indigo/annual_yields.csv")
df_do = pd.read_csv("/Users/harish/Desktop/DS_codes/indigo/daily_observations.csv")

# %% [markdown]
# # Data Preprocessing

# %%
df_cd['tot_yield']  = (df_cd['yield'])*(df_cd['area_harvested_obs'])

# %%
df_cd.head(5)
# Out:
#   adm2_code adm1_code  year  yield  area_harvested_obs  phen_gup  phen_dor  \
# 0   US01031      US01  2003  123.0              5500.0        72       295
# 1   US01031      US01  2004  111.0              6900.0        72       295
# 2   US01031      US01  2005  127.0              6000.0        72       295
# 3   US01031      US01  2006   85.0              5600.0        72       295
# 4   US01031      US01  2007   73.0              8300.0        72       295
#
#    tot_yield
# 0   676500.0
# 1   765900.0
# 2   762000.0
# 3   476000.0
# 4   605900.0

# %% [markdown]
# # Dependant variable distribution

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(df_cd['tot_yield'], bins=30)
plt.show()

# %%
df_do.head()
# Out:
#   adm2_code  year        date  doy  met_avg_t  met_extreme_cold  \
# 0   US01031  2003  2003-01-01    1  287.44855                 0
# 1   US01031  2003  2003-01-02    2  286.61816                 0
# 2   US01031  2003  2003-01-03    3  277.10223                 1
# 3   US01031  2003  2003-01-04    4  276.73196                 1
# 4   US01031  2003  2003-01-05    5  281.21307                 1
#
#    met_extreme_hot1  met_extreme_hot2   met_gdd  met_max_rh  ...  mod_lst_day  \
# 0                 0                 0  4.298554    96.77753  ...    288.11395
# 1                 0                 0  5.022919    87.06785  ...    288.11395
# 2                 0                 0  0.000000    88.82168  ...    288.11395
# 3                 0                 0  0.399628    80.37215  ...    288.11395
# 4                 0                 0  3.454437    76.90567  ...    288.11395
#
#    mod_lst_night  mod_nbar_1  mod_nbar_2  mod_nbar_3  mod_nbar_4  mod_nbar_5  \
# 0      273.58743     0.08692    0.244635     0.03991     0.07201     0.30011
# 1      273.58743     0.08596    0.245240     0.04046     0.07342     0.29704
# 2      273.58743     0.08415    0.245300     0.03945     0.07473     0.29792
# 3      273.58743     0.08143    0.247400     0.03815     0.07355     0.29815
# 4      273.58743     0.08141    0.245780     0.03817     0.07355     0.29834
#
#    mod_nbar_6  mod_nbar_7  mod_ndvi
# 0    0.259010    0.162760  0.475683
# 1    0.259070    0.159570  0.480918
# 2    0.257964    0.154409  0.489149
# 3    0.257130    0.156588  0.504729
# 4    0.261379    0.157310  0.502369
#
# [5 rows x 28 columns]

# %% [markdown]
# # Aggregating observations at county and year level

# %%
df_do_agg = df_do.groupby(['adm2_code', 'year'], as_index=False).agg({
                                          "met_avg_t": "mean", 
                                          "met_extreme_cold": "sum", 
                                          "met_extreme_hot1": "sum", 
                                          "met_extreme_hot2": "sum",
                                          "met_gdd": "sum",
                                          "met_max_rh": "mean",
                                          "met_max_t": "mean",
                                          "met_max_vpd": "mean",
                                          "met_min_rh": "mean",
                                          "met_min_t": "mean",
                                          "met_p_mm": "mean",
                                          "met_sh": "mean",
                                          "met_sr_wm2": "mean",
                                          "mod_evi": "mean",
                                          "mod_lst_day": "mean",
                                          "mod_lst_night": "mean",                        
                                          "mod_nbar_1": "mean",
                                          "mod_nbar_2": "mean",
                                          "mod_nbar_3": "mean",
                                          "mod_nbar_4": "mean",
                                          "mod_nbar_5": "mean",
                                          "mod_nbar_6": "mean",
                                          "mod_nbar_7": "mean",
                                          "mod_ndvi": "mean"})

# %%
df_do_agg.head()
# Out:
#   adm2_code  year   met_avg_t  met_extreme_cold  met_extreme_hot1  \
# 0   US01031  2003  291.446763                45                 0
# 1   US01031  2004  291.569599                37                 3
# 2   US01031  2005  291.583636                38                 1
# 3   US01031  2006  292.253343                33                37
# 4   US01031  2007  292.269954                35                29
#
#    met_extreme_hot2      met_gdd  met_max_rh   met_max_t  met_max_vpd  ...  \
# 0               105  3464.206752   94.184421  297.626227     0.131772  ...
# 1               112  3484.853876   93.969739  297.899575     0.148727  ...
# 2               129  3457.722264   94.242992  297.996766     0.155822  ...
# 3               155  3554.026852   93.804784  299.494444     0.180722  ...
# 4               149  3583.245157   91.662996  299.069181     0.247216  ...
#
#    mod_lst_day  mod_lst_night  mod_nbar_1  mod_nbar_2  mod_nbar_3  mod_nbar_4  \
# 0   298.803654     284.917569    0.094530    0.318926    0.044129    0.087745
# 1   299.133303     284.874979    0.092474    0.315844    0.043941    0.086288
# 2   298.622260     285.186738    0.091726    0.314565    0.042958    0.084878
# 3   301.355991     284.969136    0.102669    0.319451    0.048599    0.093401
# 4   300.715538     285.218698    0.094963    0.311940    0.044385    0.086954
#
#    mod_nbar_5  mod_nbar_6  mod_nbar_7  mod_ndvi
# 0    0.360954    0.290754    0.171229  0.537097
# 1    0.356350    0.289552    0.169410  0.541999
# 2    0.355302    0.285262    0.166464  0.539956
# 3    0.361230    0.299292    0.190276  0.509969
# 4    0.356378    0.291818    0.176689  0.529163
#
# [5 rows x 26 columns]

# %%
df_do_agg.shape
# Out:
# (19134, 26)

# %% [markdown]
# # Spliting dataset to train and test

# %%
df_do_train  =  df_do_agg[(df_do_agg.year != 2018)] 
df_do_test   =  df_do_agg[(df_do_agg.year == 2018)]

# %%
print(df_do_train.shape)
print(df_do_test.shape)
# Out:
# (17842, 26)
# (1292, 26)

# %%
df_cd_train  =  df_cd[(df_cd.year != 2018)] 
df_cd_test   =  df_cd[(df_cd.year == 2018)] 

print(df_cd_train.shape)
print(df_cd_test.shape)
# Out:
# (17842, 8)
# (1292, 8)

# %%
df_cd_train.columns
# Out:
# Index(['adm2_code', 'adm1_code', 'year', 'yield', 'area_harvested_obs',
#        'phen_gup', 'phen_dor', 'tot_yield'],
#       dtype='object')

# %%
train_data = pd.merge(df_do_train, df_cd_train,  on=['adm2_code','year'])
test_data = pd.merge(df_do_test, df_cd_test, on = ['adm2_code','year'])

# %% [markdown]
# # Check for null values in train data

# %%
train_data.isnull().sum()
# Out:
# adm2_code             0
# year                  0
# met_avg_t             0
# met_extreme_cold      0
# met_extreme_hot1      0
# met_extreme_hot2      0
# met_gdd               0
# met_max_rh            0
# met_max_t             0
# met_max_vpd           0
# met_min_rh            0
# met_min_t             0
# met_p_mm              0
# met_sh                0
# met_sr_wm2            0
# mod_evi               0
# mod_lst_day           0
# mod_lst_night         0
# mod_nbar_1            0
# mod_nbar_2            0
# mod_nbar_3            0
# mod_nbar_4            0
# mod_nbar_5            0
# mod_nbar_6            0
# mod_nbar_7            0
# mod_ndvi              0
# adm1_code             0
# yield                 0
# area_harvested_obs    0
# phen_gup              0
# phen_dor              0
# tot_yield             0
# dtype: int64

# %% [markdown]
# # Correlation matrix and visualization

# %%
corr_df = train_data[['met_avg_t', 'met_extreme_cold',
       'met_extreme_hot1', 'met_extreme_hot2', 'met_gdd', 'met_max_rh',
       'met_max_t', 'met_max_vpd', 'met_min_rh', 'met_min_t', 'met_p_mm',
       'met_sh', 'met_sr_wm2', 'mod_evi', 'mod_lst_day', 'mod_lst_night',
       'mod_nbar_1', 'mod_nbar_2', 'mod_nbar_3', 'mod_nbar_4', 'mod_nbar_5',
       'mod_nbar_6', 'mod_nbar_7', 'mod_ndvi',  
       'phen_gup', 'phen_dor', 'tot_yield']]

# %%
correlation_matrix = corr_df.corr().round(2)
# annot = True to print the values inside the square
plt.figure(figsize = (25,25))
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# # scatter plots for features vs dependant variable

# %%
plt.figure(figsize=(25, 25))

features_x = ['met_avg_t', 'met_extreme_cold',
       'met_extreme_hot1', 'met_extreme_hot2', 'met_gdd', 'met_max_rh',
       'met_max_t', 'met_max_vpd', 'met_min_rh', 'met_min_t', 'met_p_mm',
       'met_sh', 'met_sr_wm2', 'mod_evi', 'mod_lst_day', 'mod_lst_night',
       'mod_nbar_1', 'mod_nbar_2', 'mod_nbar_3', 'mod_nbar_4', 'mod_nbar_5',
       'mod_nbar_6', 'mod_nbar_7', 'mod_ndvi',  
       'phen_gup', 'phen_dor']

target_y = train_data['tot_yield']

for i, col in enumerate(features_x):
    plt.subplot(13, 2 , i+1)
    x = train_data[col]
    y = target_y
    plt.scatter(x, y, marker='o')
    #plt.title(col)
    plt.xlabel(col)
    plt.tight_layout()
    plt.ylabel('Yield')

# %%
test_data.head(5)
# Out:
#   adm2_code  year   met_avg_t  met_extreme_cold  met_extreme_hot1  \
# 0   US01031  2018  292.074318                23                15
# 1   US01033  2018  289.723811                55                 5
# 2   US01049  2018  288.728871                65                 0
# 3   US01071  2018  288.825399                65                 0
# 4   US01077  2018  289.448243                60                 5
#
#    met_extreme_hot2      met_gdd  met_max_rh   met_max_t  met_max_vpd  ...  \
# 0               101  3600.356162   93.197911  298.240500     0.186250  ...
# 1                96  3062.760258   89.895382  295.539573     0.261688  ...
# 2                59  2826.789672   93.649018  294.318480     0.129740  ...
# 3                76  2870.229920   93.719454  294.630675     0.136445  ...
# 4                98  3005.175238   90.937651  295.443223     0.231314  ...
#
#    mod_nbar_5  mod_nbar_6  mod_nbar_7  mod_ndvi  adm1_code  yield  \
# 0    0.348599    0.273898    0.155609  0.576726       US01    NaN
# 1    0.337210    0.283479    0.165634  0.521074       US01    NaN
# 2    0.346739    0.262223    0.136054  0.617837       US01    NaN
# 3    0.328266    0.249241    0.130008  0.605201       US01    NaN
# 4    0.354312    0.288509    0.161967  0.546959       US01    NaN
#
#    area_harvested_obs  phen_gup  phen_dor  tot_yield
# 0                 NaN        72       295        NaN
# 1                 NaN        84       281        NaN
# 2                 NaN        73       299        NaN
# 3                 NaN        77       292        NaN
# 4                 NaN        78       284        NaN
#
# [5 rows x 32 columns]

# %%
train_data.columns
# Out:
# Index(['adm2_code', 'year', 'met_avg_t', 'met_extreme_cold',
#        'met_extreme_hot1', 'met_extreme_hot2', 'met_gdd', 'met_max_rh',
#        'met_max_t', 'met_max_vpd', 'met_min_rh', 'met_min_t', 'met_p_mm',
#        'met_sh', 'met_sr_wm2', 'mod_evi', 'mod_lst_day', 'mod_lst_night',
#        'mod_nbar_1', 'mod_nbar_2', 'mod_nbar_3', 'mod_nbar_4', 'mod_nbar_5',
#        'mod_nbar_6', 'mod_nbar_7', 'mod_ndvi', 'adm1_code', 'yield',
#        'area_harvested_obs', 'phen_gup', 'phen_dor', 'tot_yield'],
#       dtype='object')

# %% [markdown]
# # Feature selection for model training

# %%
features = ['met_avg_t', 'met_extreme_cold',
       'met_extreme_hot1', 'met_extreme_hot2', 'met_gdd', 'met_max_rh',
       'met_max_t', 'met_max_vpd', 'met_min_rh', 'met_min_t', 'met_p_mm',
       'met_sh', 'met_sr_wm2', 'mod_evi', 'mod_lst_day', 'mod_lst_night',
       'mod_nbar_1', 'mod_nbar_2', 'mod_nbar_3', 'mod_nbar_4', 'mod_nbar_5',
       'mod_nbar_6', 'mod_nbar_7', 'mod_ndvi',
       'phen_gup', 'phen_dor']

response = ['tot_yield']

# %%
X = train_data[features]
x_test = test_data[features]

y = train_data[response]
y_test = test_data[response]

# %% [markdown]
# # Preparing Validation data from train dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Scaling features and response variable for modeling

# %%
# Feature Scaling

from sklearn.preprocessing import MinMaxScaler
sc_X = MinMaxScaler()
X_train_scaled = sc_X.fit_transform(X_train)
X_val_scaled = sc_X.transform(X_val)

# %%
# Response Scaling

from sklearn.preprocessing import MinMaxScaler
sc_Y = MinMaxScaler()
y_train_scaled = sc_Y.fit_transform(y_train)
y_val_scaled = sc_Y.transform(y_val)

# %% [markdown]
# # Gradient Boosting Model

# %%
from sklearn.metrics import r2_score
from sklearn import metrics
import math
import warnings
warnings.simplefilter("ignore")

from sklearn.ensemble import GradientBoostingRegressor


gbd = GradientBoostingRegressor(n_estimators=100, max_depth=3, random_state=0)
model_gb = gbd.fit(X_train_scaled,y_train_scaled)
y_pred_gb = model_gb.predict(X_val_scaled)


r2_gb = r2_score(y_val_scaled,y_pred_gb)
mse_gb = metrics.mean_squared_error(y_val_scaled, y_pred_gb)
rmse_gb = math.sqrt(mse_gb)

print("MSE, Root Mean square error is "+str(mse_gb))
print("RMSE, Root Mean square error is "+str(rmse_gb))
print("R2, Coefficient of Determination is "+str(r2_gb))
# Out:
# MSE, Root Mean square error is 0.005640561123097484
# RMSE, Root Mean square error is 0.07510366917200174
# R2, Coefficient of Determination is 0.7580613992667216

# %% [markdown]
# # plotting the Actual vs Predicted

# %%
plt.scatter(y_val_scaled, y_pred_gb)
plt.show()

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.metrics import r2_score
from sklearn import metrics
import math
import warnings
warnings.simplefilter("ignore")

from sklearn.ensemble import RandomForestRegressor


rfr = RandomForestRegressor(n_estimators=100, max_depth=3, random_state=0)
model_rf = rfr.fit(X_train_scaled,y_train_scaled)
y_pred_rf = model_rf.predict(X_val_scaled)


r2_rf = r2_score(y_val_scaled,y_pred_rf)
mse_rf = metrics.mean_squared_error(y_val_scaled, y_pred_rf)
rmse_rf = math.sqrt(mse_rf)

print("MSE, Root Mean square error is "+str(mse_rf))
print("RMSE, Root Mean square error is "+str(rmse_rf))
print("R2, Coefficient of Determination is "+str(r2_rf))
# Out:
# MSE, Root Mean square error is 0.009128136523535437
# RMSE, Root Mean square error is 0.0955412817767034
# R2, Coefficient of Determination is 0.608470056504992

# %%
plt.scatter(y_val_scaled, y_pred_rf)
plt.show()

# %% [markdown]
# # Support Vector regressor

# %%
from sklearn.metrics import r2_score
from sklearn import metrics
import math
import warnings
warnings.simplefilter("ignore")

from sklearn.svm import SVR


svr = SVR(kernel= 'rbf')
model_svr = svr.fit(X_train_scaled,y_train_scaled)
y_pred_svr = model_svr.predict(X_val_scaled)


r2_svr = r2_score(y_val_scaled,y_pred_svr)
mse_svr = metrics.mean_squared_error(y_val_scaled, y_pred_svr)
rmse_svr = math.sqrt(mse_svr)

print("MSE, Root Mean square error is "+str(mse_svr))
print("RMSE, Root Mean square error is "+str(rmse_svr))
print("R2, Coefficient of Determination is "+str(r2_svr))
# Out:
# MSE, Root Mean square error is 0.006109901682601923
# RMSE, Root Mean square error is 0.07816586008355517
# R2, Coefficient of Determination is 0.7379301400257045

# %%
plt.scatter(y_val_scaled, y_pred_svr)
plt.show()

# %% [markdown]
# # Decision tree regressor

# %%
from sklearn.metrics import r2_score
from sklearn import metrics
import math
import warnings
warnings.simplefilter("ignore")

from sklearn.tree import DecisionTreeRegressor


dtr = DecisionTreeRegressor()
model_dtr = dtr.fit(X_train_scaled,y_train_scaled)
y_pred_dtr = model_dtr.predict(X_val_scaled)


r2_dtr = r2_score(y_val_scaled,y_pred_dtr)
mse_dtr = metrics.mean_squared_error(y_val_scaled, y_pred_dtr)
rmse_dtr = math.sqrt(mse_dtr)

print("MSE, Root Mean square error is "+str(mse_dtr))
print("RMSE, Root Mean square error is "+str(rmse_dtr))
print("R2, Coefficient of Determination is "+str(r2_dtr))
# Out:
# MSE, Root Mean square error is 0.007032929441686594
# RMSE, Root Mean square error is 0.08386256281372871
# R2, Coefficient of Determination is 0.6983390355952491

# %%
plt.scatter(y_val_scaled, y_pred_dtr)
plt.show()

# %% [markdown]
# # Prediction

# %%
from sklearn.preprocessing import MinMaxScaler
sc_X = MinMaxScaler()

x_test = test_data[features]
y_test = test_data[response]

X_train_scaled = sc_X.fit_transform(X_train)
x_test_scaled = sc_X.transform(x_test)

sc_Y = MinMaxScaler()
y_train_scaled = sc_Y.fit_transform(y_train)

# %%
test_data.head(5)
# Out:
#   adm2_code  year   met_avg_t  met_extreme_cold  met_extreme_hot1  \
# 0   US01031  2018  292.074318                23                15
# 1   US01033  2018  289.723811                55                 5
# 2   US01049  2018  288.728871                65                 0
# 3   US01071  2018  288.825399                65                 0
# 4   US01077  2018  289.448243                60                 5
#
#    met_extreme_hot2      met_gdd  met_max_rh   met_max_t  met_max_vpd  ...  \
# 0               101  3600.356162   93.197911  298.240500     0.186250  ...
# 1                96  3062.760258   89.895382  295.539573     0.261688  ...
# 2                59  2826.789672   93.649018  294.318480     0.129740  ...
# 3                76  2870.229920   93.719454  294.630675     0.136445  ...
# 4                98  3005.175238   90.937651  295.443223     0.231314  ...
#
#    mod_nbar_5  mod_nbar_6  mod_nbar_7  mod_ndvi  adm1_code  yield  \
# 0    0.348599    0.273898    0.155609  0.576726       US01    NaN
# 1    0.337210    0.283479    0.165634  0.521074       US01    NaN
# 2    0.346739    0.262223    0.136054  0.617837       US01    NaN
# 3    0.328266    0.249241    0.130008  0.605201       US01    NaN
# 4    0.354312    0.288509    0.161967  0.546959       US01    NaN
#
#    area_harvested_obs  phen_gup  phen_dor  tot_yield
# 0                 NaN        72       295        NaN
# 1                 NaN        84       281        NaN
# 2                 NaN        73       299        NaN
# 3                 NaN        77       292        NaN
# 4                 NaN        78       284        NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# # Predictions with Gradient Boost Model

# %%
for i in range(len(test_data)):
    test_data_features = pd.DataFrame(data = test_data.loc[i,features]).swapaxes("index", "columns")
    y_pred_scaled = model_gb.predict(sc_X.transform(test_data_features))
    y_pred = sc_Y.inverse_transform([y_pred_scaled])
    test_data.loc[i, 'tot_yield'] = y_pred[0,0]
    
test_data.to_csv("/Users/harish/Desktop/DS_codes/indigo/results_gb.csv")

# %%
for i in range(len(test_data)):
    test_data_features = pd.DataFrame(data = test_data.loc[i,features]).swapaxes("index", "columns")
    y_pred_scaled = model_rf.predict(sc_X.transform(test_data_features))
    y_pred = sc_Y.inverse_transform([y_pred_scaled])
    test_data.loc[i, 'tot_yield'] = y_pred[0,0]
    
    
test_data.to_csv("/Users/harish/Desktop/DS_codes/indigo/results_rf.csv")

# %%
for i in range(len(test_data)):
    test_data_features = pd.DataFrame(data = test_data.loc[i,features]).swapaxes("index", "columns")
    y_pred_scaled = model_svr.predict(sc_X.transform(test_data_features))
    y_pred = sc_Y.inverse_transform([y_pred_scaled])
    test_data.loc[i, 'tot_yield'] = y_pred[0,0]
    
    
test_data.to_csv("/Users/harish/Desktop/DS_codes/indigo/results_svr.csv")

# %%
for i in range(len(test_data)):
    test_data_features = pd.DataFrame(data = test_data.loc[i,features]).swapaxes("index", "columns")
    y_pred_scaled = model_dtr.predict(sc_X.transform(test_data_features))
    y_pred = sc_Y.inverse_transform([y_pred_scaled])
    test_data.loc[i, 'tot_yield'] = y_pred[0,0]
    
    
test_data.to_csv("/Users/harish/Desktop/DS_codes/indigo/results_dtr.csv")

# %% [markdown]
# # Predicting US annual yield for 2018

# %%
df_ay.head()
# Out:
#    year  yield
# 0  1990  118.5
# 1  1991  108.6
# 2  1992  131.5
# 3  1993  100.7
# 4  1994  138.6

# %%
df_ay['sma_2'] = df_ay.iloc[:,1].rolling(window=2).mean()
df_ay['sma_3'] = df_ay.iloc[:,1].rolling(window=3).mean()

# %%
from matplotlib import pyplot

pyplot.figure(figsize = (18,9))
pyplot.grid(True)
pyplot.xlabel('Year',fontsize=18)
pyplot.ylabel('Yield',fontsize=18)
pyplot.plot(df_ay['year'], df_ay['yield'],label='Yield')
pyplot.plot(df_ay['year'], df_ay['sma_2'],label='SMA 2 years')
pyplot.plot(df_ay['year'], df_ay['sma_3'],label='SMA 3 years')
pyplot.legend(loc=2)
pyplot.show()

# %% [markdown]
# # Assuming that Annual yield is in billions - bushnels which constitues corn yield as a portion

# %%
df_cd.head(5)
# Out:
#   adm2_code adm1_code  year  yield  area_harvested_obs  phen_gup  phen_dor  \
# 0   US01031      US01  2003  123.0              5500.0        72       295
# 1   US01031      US01  2004  111.0              6900.0        72       295
# 2   US01031      US01  2005  127.0              6000.0        72       295
# 3   US01031      US01  2006   85.0              5600.0        72       295
# 4   US01031      US01  2007   73.0              8300.0        72       295
#
#    tot_yield
# 0   676500.0
# 1   765900.0
# 2   762000.0
# 3   476000.0
# 4   605900.0

# %%
df_cd_agg = df_cd.groupby('year', as_index = False).agg({'tot_yield': 'sum'})

# %%
df_cd_agg['corn_yield'] = df_cd_agg['tot_yield']/1000000000

# %%
df_cd_agg.head(5)
# Out:
#    year     tot_yield  corn_yield
# 0  2003  9.858881e+09    9.858881
# 1  2004  1.155270e+10   11.552701
# 2  2005  1.087125e+10   10.871248
# 3  2006  1.030671e+10   10.306711
# 4  2007  1.275055e+10   12.750553

# %%
df_annual_yield = pd.merge(df_cd_agg, df_ay, on = ['year'])

# %%
df_annual_yield.head(5)
# Out:
#    year     tot_yield  corn_yield  yield   sma_2       sma_3
# 0  2003  9.858881e+09    9.858881  142.2  135.75  136.566667
# 1  2004  1.155270e+10   11.552701  160.3  151.25  143.933333
# 2  2005  1.087125e+10   10.871248  147.9  154.10  150.133333
# 3  2006  1.030671e+10   10.306711  149.1  148.50  152.433333
# 4  2007  1.275055e+10   12.750553  150.7  149.90  149.233333

# %%
df_annual_yield['corn_percentage'] = (df_annual_yield['corn_yield']/df_annual_yield['yield'])*100

# %%
df_annual_yield.tail(5)
# Out:
#     year     tot_yield  corn_yield  yield   sma_2       sma_3  corn_percentage
# 10  2013  1.272605e+10   12.726051  158.1  140.60  142.666667         8.049368
# 11  2014  1.312776e+10   13.127763  171.0  164.55  150.733333         7.677054
# 12  2015  1.226925e+10   12.269246  168.4  169.70  165.833333         7.285776
# 13  2016  1.381617e+10   13.816172  174.6  171.50  171.333333         7.913042
# 14  2017  1.340889e+10   13.408887  176.6  175.60  173.200000         7.592802

# %%
df_annual_yield['corn_percentage'].mean()
# Out:
# 7.649825791378821

# %% [markdown]
# # Insight : on an average, the corn yield is 7.7% of annual  yield

# %%
us_corn = pd.read_csv("/Users/harish/Desktop/DS_codes/indigo/results_dtr.csv")

# %%
us_corn_2018 = us_corn.groupby('year', as_index = False).agg({'tot_yield': 'sum'})

# %%
us_corn_2018['corn_yield'] = us_corn_2018['tot_yield']/1000000000

# %%
us_corn_2018
# Out:
#    year     tot_yield  corn_yield
# 0  2018  1.324023e+10    13.24023

# %%
us_yield_2018 = (us_corn_2018['corn_yield']*100)/7.7

# %%
print("Predicted 2018 annual yeild is: " +str(us_yield_2018.values))
# Out:
# Predicted 2018 annual yeild is: [171.95104384]

# %% [markdown]
# # Predicted 2018 annual yield is 172
